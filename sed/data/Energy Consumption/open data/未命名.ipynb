# %%
import pandas as pd
import json
import numpy as np

# %%
# Out:
# [WinError 2] 系统找不到指定的文件。: '/d/'
# C:\Users\Lu

# %%
df = pd.read_excel('Open Data Human Readable20190401.xlsx')

# %%
df
# Out:
#                 identifier                                              title  \
# 0         DOE-019-NP-10004                                     Agency Parking
# 1       DOE-019-4578239451  Congressional and Intergovernmental Affairs we...
# 2        DOE-019-100675435             DATA Act for U.S. Department of Energy
# 3        DOE-019-100675435             DATA Act for U.S. Department of Energy
# 4      DOE-019-FITARA-0001                           Agency IT Policy Archive
# 5      DOE-019-FITARA-0003               CIO Governance Board Membership List
# 6      DOE-019-FITARA-0004                              DOE FITARA Milestones
# 7       DOE-019-4381227569            DOE Hearings and Appeals Case Decisions
# 8       DOE-019-0334675236               DOE IT Reform Cost Savings/Avoidance
# 9       DOE-019-1254627400                          Enterprise Data Inventory
# 10      DOE-019-3665989539                                         Energy.gov
# ...

# %%
with open("../chicago/socrata_metadata.json","r") as data:
    data = json.loads(data.read())

# %%
print(data)
# Out:
# {'tableId': 1014679, 'rights': ['read'], 'oid': 4736793, 'publicationStage': 'published', 'attribution': 'City of Chicago', 'description': "Displays several units of energy consumption for households, businesses, and industries in the City of Chicago during 2010. Electric  The data was aggregated from ComEd and Peoples Natural Gas by Accenture. Electrical and gas usage data comprises 88 percent of Chicago's buildings in 2010. The electricity data comprises 68 percent of overall electrical usage in the city while gas data comprises 81 percent of all gas consumption in Chicago for 2010.\r\n\r\nCensus blocks with less than 4 accounts is displayed at the Community Area without further geographic identifiers. This dataset also contains selected variables describing selected characteristics of the Census block population, physical housing, and occupancy.", 'viewType': 'tabular', 'publicationDate': 1375455563, 'category': 'Environment & Sustainable Development', 'ratings': {'rating': 100}, 
# ...

# %%
NotebookApp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c30a46683120> in <module>
# ----> 1 NotebookApp
#
# NameError: name 'NotebookApp' is not defined

# %%
cd /root/.jupyter/
# Out:
# [WinError 3] 系统找不到指定的路径。: '/root/.jupyter/'
# D:\UW\DIRECT\KPMG\open data
