# %%
import numpy as np
import pandas as pd

# %%
zipcodes = pd.read_csv('Seattle_Building_Energy_Benchmarking_2016_raw.csv',  index_col='OSEBuildingID', usecols=['OSEBuildingID','ZipCode'])
data_2015 = pd.read_csv('Seattle_Building_Energy_Benchmarking_2015_raw.csv')
data_2016 = pd.read_csv('Seattle_Building_Energy_Benchmarking_2016_raw.csv')
data_2017 = pd.read_csv('Seattle_Building_Energy_Benchmarking_2017_raw.csv')

# %% [markdown]
# ### Functions for cleaning data

# %%
def fill_propertytype(df):
    for i in range(len(df)):
        if pd.isnull(df['LargestPropertyUseType'][i]):
            df.at[i, 'LargestPropertyUseType'] = df['PrimaryPropertyType'][i]
        else:
            continue         

def reclassify_buildingtype(df):
    residential = ['Multifamily LR (1-4)', 'Multifamily MR (5-9)', 'Multifamily HR (10+)']
    specialty = ['Campus', 'SPS-District K-12', 'Nonresidential COS']
    for i in range(len(df)):
        if df['BuildingType'][i] in residential:
            df.at[i, 'BuildingType'] = 'Residential'
        elif df['BuildingType'][i] in specialty:
            df.at[i, 'BuildingType'] = 'Specialty'
        else:
            continue           

def remove_outliers(df):   
    for i in range(len(df)):
        if pd.isnull(df['Outlier'][i]):
            continue 
        else:
            df.drop([i], inplace=True)
    df.reset_index(inplace=True)
            
def remove_empty_rows(df):   
    for i in range(len(df)):
        if pd.isnull(df['ZipCode'][i]):
             df.drop([i], inplace=True)
        else:
            continue
    df.reset_index(inplace=True)
            
def remove_columns_Seattle_2015(df):
    df.drop(['PrimaryPropertyType',
             'PropertyName',
             'TaxParcelIdentificationNumber', 
             'Location',
             'CouncilDistrictCode',
             'Neighborhood',
             'DefaultData',
             'Comment',
             'ComplianceStatus',
             'Outlier',
             '2010 Census Tracts',
             'Seattle Police Department Micro Community Policing Plan Areas',
             'SPD Beats',
             'NumberofBuildings',
             'NumberofFloors',
             'PropertyGFAParking',
             'PropertyGFABuilding(s)',
             'ListOfAllPropertyUseTypes',
             'LargestPropertyUseTypeGFA',
             'SecondLargestPropertyUseType',
             'SecondLargestPropertyUseTypeGFA',
             'ThirdLargestPropertyUseType',
             'ThirdLargestPropertyUseTypeGFA',
             'YearsENERGYSTARCertified',
             'ENERGYSTARScore',
             'GHGEmissions(MetricTonsCO2e)',
             'GHGEmissionsIntensity(kgCO2e/ft2)',
             'City Council Districts',
             'Electricity(kWh)',
             'NaturalGas(therms)',
             'Zip Codes',
             'OtherFuelUse(kBtu)'
           ], inplace=True, axis=1)            

def remove_columns_Seattle_2016(df):
    df.drop(['PrimaryPropertyType',
             'PropertyName',
             'Address',
             'TaxParcelIdentificationNumber', 
             'CouncilDistrictCode',
             'Neighborhood',
             'Latitude',
             'Longitude',
             'DefaultData',
             'Comments',
             'ComplianceStatus',
             'Outlier',
             'NumberofBuildings',
             'NumberofFloors',
             'PropertyGFAParking',
             'PropertyGFABuilding(s)',
             'ListOfAllPropertyUseTypes',
             'LargestPropertyUseTypeGFA',
             'SecondLargestPropertyUseType',
             'SecondLargestPropertyUseTypeGFA',
             'ThirdLargestPropertyUseType',
             'ThirdLargestPropertyUseTypeGFA',
             'YearsENERGYSTARCertified',
             'ENERGYSTARScore',
             'TotalGHGEmissions',
             'GHGEmissionsIntensity',
             'Electricity(kWh)',
             'NaturalGas(therms)',
           ], inplace=True, axis=1)

def remove_columns_Seattle_2017(df):
    df.drop(['PrimaryPropertyType',
             'PropertyName',
             'Address',
             'TaxParcelIdentificationNumber', 
             'CouncilDistrictCode',
             'Neighborhood',
             'Latitude',
             'Longitude',
             'DefaultData',
             'ComplianceStatus',
             'Outlier',
             'NumberofBuildings',
             'NumberofFloors',
             'PropertyGFAParking',
             'PropertyGFABuilding(s)',
             'ListOfAllPropertyUseTypes',
             'LargestPropertyUseTypeGFA',
             'SecondLargestPropertyUseType',
             'SecondLargestPropertyUseTypeGFA',
             'ThirdLargestPropertyUseType',
             'ThirdLargestPropertyUseTypeGFA',
             'YearsENERGYSTARCertified',
             'ENERGYSTARScore',
             'TotalGHGEmissions',
             'GHGEmissionsIntensity',
             'Electricity(kWh)',
             'NaturalGas(therms)',
           ], inplace=True, axis=1)

def remove_commas(df):
    column_names_1 = np.array(df.columns[7:])
    
    if 'BuildingID' in df.columns:
        column_names_1 = np.append(column_names_1, ['BuildingID'])
    
    for i in range(len(column_names_1)):
        column = column_names_1[i]
        df[column] = pd.to_numeric(df[column].astype(str).str.replace(',',''), errors='coerce')
        
def convert_to_int(df):
    if 'BuildingID' in df.columns:
        column_names_2 = ['BuildingID', 'DataYear', 'ZipCode', 'YearBuilt']
    else:
        column_names_2 = ['DataYear', 'ZipCode', 'YearBuilt']
    
    for i in range(len(column_names_2)):
        column = column_names_2[i]
        df[column] = df[column].astype('int64')

def reset_zipcodes(df):
    df.set_index('OSEBuildingID', inplace=True)
    df = pd.concat([zipcodes, data_2015], sort=True, axis=1)
    df.reset_index(inplace=True)
    
    return df

def restructure_columns(df):
    df['City'] = 'Seattle'
    df['State'] = 'WA'
    df.rename({'LargestPropertyUseType':'PrimaryPropertyUse'}, axis='columns', inplace=True)
    df = df[['OSEBuildingID',
             'DataYear',
             'City', 
             'State',
             'ZipCode',
             'BuildingType',
             'PrimaryPropertyUse',
             'YearBuilt',
             'PropertyGFATotal',
             'SiteEUI(kBtu/sf)',
             'SiteEUIWN(kBtu/sf)',
             'SourceEUI(kBtu/sf)',
             'SourceEUIWN(kBtu/sf)',
             'SiteEnergyUse(kBtu)',
             'SiteEnergyUseWN(kBtu)',
             'SteamUse(kBtu)',
             'Electricity(kBtu)',
             'NaturalGas(kBtu)']]
    
    return df

def reset_index(df):
    df.rename(index=str, columns={'OSEBuildingID':'BuildingID'}, inplace=True)
    df.set_index('BuildingID', inplace=True)

def clean_data_Seattle_2015(df): 
    fill_propertytype(df)
    reclassify_buildingtype(df)
    remove_outliers(df)
    remove_columns_Seattle_2015(df)
    df = reset_zipcodes(df)
    df.dropna(inplace=True)
    df = restructure_columns(df)
    remove_commas(df)
    convert_to_int(df)
    reset_index(df)
    return df 
    
def clean_data_Seattle_2016(df): 
    fill_propertytype(df)
    reclassify_buildingtype(df)
    remove_outliers(df)
    remove_columns_Seattle_2016(df)
    df.dropna(inplace=True)
    df = restructure_columns(df)
    remove_commas(df)
    convert_to_int(df)
    reset_index(df)
    return df
    
    
def clean_data_Seattle_2017(df): 
    fill_propertytype(df)
    reclassify_buildingtype(df)
    remove_outliers(df)
    remove_columns_Seattle_2017(df)
    remove_empty_rows(df)
    df.fillna(0, inplace=True)
    df = restructure_columns(df)
    remove_commas(df)
    convert_to_int(df)
    reset_index(df)
    return df

# %% [markdown]
# ### Cleaning and exporting data

# %%
data_2015 = clean_data_Seattle_2015(data_2015)
data_2015.head()
# Out:
#             DataYear     City State  ZipCode    BuildingType  \
# BuildingID
# 1               2015  Seattle    WA    98101  NonResidential
# 2               2015  Seattle    WA    98101  NonResidential
# 3               2015  Seattle    WA    98101  NonResidential
# 8               2015  Seattle    WA    98121  NonResidential
# 9               2015  Seattle    WA    98101       Specialty
#
#            PrimaryPropertyUse  YearBuilt  PropertyGFATotal  SiteEUI(kBtu/sf)  \
# BuildingID
# 1                       Hotel       1927             88434              78.9
# 2                       Hotel       1996            103566              94.4
# 3                       Hotel       1969            961990              96.6
# 8                       Hotel       1980            119890             120.1
# 9              Police Station       1999             97288             135.7
#
#             SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# BuildingID
# 1                         80.3               173.5                 175.1
# 2                         99.0               191.3                 195.2
# 3                         99.7               242.7                 246.5
# 8                        122.1               228.8                 227.1
# 9                        146.9               313.5                 321.6
#
#             SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# BuildingID
# 1                       6981428                7097539         2023032
# 2                       8354235                8765788               0
# 3                      73130656               75506272        19660404
# 8                      14829099               15078243               0
# 9                      12051984               13045258               0
#
#             Electricity(kBtu)  NaturalGas(kBtu)
# BuildingID
# 1                     3686160           1272388
# 2                     3905411           4448985
# 3                    49762435           3709900
# 8                     6066245           8763105
# 9                     7271004           4781283

# %%
data_2016 = clean_data_Seattle_2016(data_2016)
data_2016.head()
# Out:
# C:\Users\cjros\Anaconda3\lib\site-packages\ipykernel_launcher.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\cjros\Anaconda3\lib\site-packages\ipykernel_launcher.py:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\cjros\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#             DataYear     City State  ZipCode    BuildingType  \
# BuildingID
# 1               2016  Seattle    WA    98101  NonResidential
# 2               2016  Seattle    WA    98101  NonResidential
# 3               2016  Seattle    WA    98101  NonResidential
# 5               2016  Seattle    WA    98101  NonResidential
# 8               2016  Seattle    WA    98121  NonResidential
#
#            PrimaryPropertyUse  YearBuilt  PropertyGFATotal  SiteEUI(kBtu/sf)  \
# BuildingID
# 1                       Hotel       1927             88434         81.699997
# 2                       Hotel       1996            103566         94.800003
# 3                       Hotel       1969            956110         96.000000
# 5                       Hotel       1926             61320        110.800003
# 8                       Hotel       1980            175580        114.800003
#
#             SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# BuildingID
# 1                    84.300003          182.500000            189.000000
# 2                    97.900002          176.100006            179.399994
# 3                    97.699997          241.899994            244.100006
# 5                   113.300003          216.199997            224.000000
# 8                   118.699997          211.399994            215.600006
#
#             SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# BuildingID
# 1                     7226362.5              7456910.0      2003882.00
# 2                     8387933.0              8664479.0            0.00
# 3                    72587024.0             73937112.0     21566554.00
# 5                     6794584.0              6946800.5      2214446.25
# 8                    14172606.0             14656503.0            0.00
#
#             Electricity(kBtu)  NaturalGas(kBtu)
# BuildingID
# 1                     3946027           1276453
# 2                     3242851           5145082
# 3                    49526664           1493800
# 5                     2768924           1811213
# 8                     5368607           8803998

# %%
data_2017 = clean_data_Seattle_2017(data_2017)
data_2017.head()
# Out:
# C:\Users\cjros\Anaconda3\lib\site-packages\ipykernel_launcher.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\cjros\Anaconda3\lib\site-packages\ipykernel_launcher.py:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             DataYear     City State  ZipCode    BuildingType  \
# BuildingID
# 1               2017  Seattle    WA    98101  NonResidential
# 2               2017  Seattle    WA    98101  NonResidential
# 3               2017  Seattle    WA    98101       Specialty
# 5               2017  Seattle    WA    98101  NonResidential
# 8               2017  Seattle    WA    98121  NonResidential
#
#            PrimaryPropertyUse  YearBuilt  PropertyGFATotal  SiteEUI(kBtu/sf)  \
# BuildingID
# 1                       Hotel       1927             88434         83.199997
# 2                       Hotel       1996            103566         88.199997
# 3                       Hotel       1969            956110         98.400002
# 5                       Hotel       1926             61320        120.199997
# 8                       Hotel       1980            175580        116.099998
#
#             SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# BuildingID
# 1                    82.300003          184.399994            181.600006
# 2                    86.800003          163.800003            159.800003
# 3                    98.199997          242.899994            242.600006
# 5                   119.000000          234.300003            230.300003
# 8                   114.099998          209.899994            205.500000
#
#             SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# BuildingID
# 1                     7361655.0              7274452.5      2122835.75
# 2                     7804844.5              7678810.5            0.00
# 3                    74470328.0             74311368.0     24313482.00
# 5                     7372221.5              7294312.0      2228119.50
# 8                    14335778.0             14081251.0            0.00
#
#             Electricity(kBtu)  NaturalGas(kBtu)
# BuildingID
# 1                3.950356e+06      1.288463e+06
# 2                3.016757e+06      4.788087e+06
# 3                4.871284e+07      1.444000e+06
# 5                3.008514e+06      2.135588e+06
# 8                5.198202e+06      9.137576e+06

# %%
data_2015.to_csv(r'C:\Users\cjros\DIRECT\Capstone\Data\EnergyConsumption\Seattle\Seattle_Energy_Consumption_2015_cleaned.csv')
data_2016.to_csv(r'C:\Users\cjros\DIRECT\Capstone\Data\EnergyConsumption\Seattle\Seattle_Energy_Consumption_2016_cleaned.csv')
data_2017.to_csv(r'C:\Users\cjros\DIRECT\Capstone\Data\EnergyConsumption\Seattle\Seattle_Energy_Consumption_2017_cleaned.csv')

# %% [markdown]
# ### Code to combine all Seattle building energy data into one .csv file

# %%
data_combined = pd.concat([data_2015,data_2016,data_2017], sort=False, ignore_index=False)
data_combined.reset_index(inplace=True)
data_combined
# Out:
#      BuildingID  DataYear     City State  ZipCode    BuildingType  \
# 0             1      2015  Seattle    WA    98101  NonResidential
# 1             2      2015  Seattle    WA    98101  NonResidential
# 2             3      2015  Seattle    WA    98101  NonResidential
# 3             8      2015  Seattle    WA    98121  NonResidential
# 4             9      2015  Seattle    WA    98101       Specialty
# 5            10      2015  Seattle    WA    98101  NonResidential
# 6            11      2015  Seattle    WA    98101  NonResidential
# 7            12      2015  Seattle    WA    98104  NonResidential
# 8            13      2015  Seattle    WA    98104     Residential
# 9            15      2015  Seattle    WA    98101  NonResidential
# 10           16      2015  Seattle    WA    98101  NonResidential
# 11           17      2015  Seattle    WA    98104  NonResidential
# 12           18      2015  Seattle    WA    98101  NonResidential
# 13           19      2015  Seattle    WA    98101  NonResidential
# 14           21      2015  Seattle    WA    98154       Specialty
# 15           22      2015  Seattle    WA    98104  NonResidential
# 16           23      2015  Seattle    WA    98104  NonResidential
# 17           24      2015  Seattle    WA    98104  NonResidential
# 18           25      2015  Seattle    WA    98104  NonResidential
# 19           26      2015  Seattle    WA    98104  NonResidential
# 20           27      2015  Seattle    WA    98104  NonResidential
# 21           28      2015  Seattle    WA    98118       Specialty
# 22           29      2015  Seattle    WA    98105  NonResidential
# 23           30      2015  Seattle    WA    98121  NonResidential
# 24           31      2015  Seattle    WA    98101  NonResidential
# 25           32      2015  Seattle    WA    98101  NonResidential
# 26           33      2015  Seattle    WA    98101  NonResidential
# 27           34      2015  Seattle    WA    98112       Specialty
# 28           35      2015  Seattle    WA    98121  NonResidential
# 29           36      2015  Seattle    WA    98125       Specialty
# ...         ...       ...      ...   ...      ...             ...
# 9890     50,175      2017  Seattle    WA    98115     Residential
# 9891     50,176      2017  Seattle    WA    98105     Residential
# 9892     50,177      2017  Seattle    WA    98118     Residential
# 9893     50,178      2017  Seattle    WA    98122     Residential
# 9894     50,179      2017  Seattle    WA    98119     Residential
# 9895     50,180      2017  Seattle    WA    98144     Residential
# 9896     50,181      2017  Seattle    WA    98144     Residential
# 9897     50,182      2017  Seattle    WA    98105     Residential
# 9898     50,185      2017  Seattle    WA    98103     Residential
# 9899     50,186      2017  Seattle    WA    98104  NonResidential
# 9900     50,187      2017  Seattle    WA    98116     Residential
# 9901     50,188      2017  Seattle    WA    98121  NonResidential
# 9902     50,190      2017  Seattle    WA    98109     Residential
# 9903     50,191      2017  Seattle    WA    98119     Residential
# 9904     50,194      2017  Seattle    WA    98107  NonResidential
# 9905     50,196      2017  Seattle    WA    98125       Specialty
# 9906     50,212      2017  Seattle    WA    98112       Specialty
# 9907     50,219      2017  Seattle    WA    98122       Specialty
# 9908     50,237      2017  Seattle    WA    98119  NonResidential
# 9909     50,248      2017  Seattle    WA    98107     Residential
# 9910     50,249      2017  Seattle    WA    98122     Residential
# 9911     50,253      2017  Seattle    WA    98109     Residential
# 9912     50,254      2017  Seattle    WA    98104     Residential
# 9913     50,261      2017  Seattle    WA    98126     Residential
# 9914     50,262      2017  Seattle    WA    98109     Residential
# 9915     50,263      2017  Seattle    WA    98121     Residential
# 9916     50,268      2017  Seattle    WA    98122     Residential
# 9917     50,272      2017  Seattle    WA    98122     Residential
# 9918     50,284      2017  Seattle    WA    98107     Residential
# 9919     50,289      2017  Seattle    WA    98104     Residential
#
#                          PrimaryPropertyUse  YearBuilt  PropertyGFATotal  \
# 0                                     Hotel       1927             88434
# 1                                     Hotel       1996            103566
# 2                                     Hotel       1969            961990
# 3                                     Hotel       1980            119890
# 4                            Police Station       1999             97288
# 5                                     Hotel       1926             83008
# 6     Other - Entertainment/Public Assembly       1926            102761
# 7                                     Hotel       1904            163984
# 8                       Multifamily Housing       1910             63712
# 9                                     Hotel       1969            153163
# 10                                    Hotel       1998            333176
# 11                                    Hotel       1928             65009
# 12                                    Hotel       1980            315952
# 13                                    Hotel       1922             67390
# 14                                  Library       2004            412000
# 15           Fitness Center/Health Club/Gym       1930            103911
# 16                                    Hotel       1983            416281
# 17                      Social/Meeting Hall       1907             57452
# 18                                    Hotel       1916            104352
# 19                               Courthouse       1916            540360
# 20                                    Other       1985            385274
# 21                              K-12 School       1961             56228
# 22                                    Hotel       2001             88592
# 23                       College/University       1928            126593
# 24                    Automobile Dealership       1930             67224
# 25                                    Hotel       1991            158676
# 26                                    Hotel       2001            171866
# 27                              K-12 School       1955            126351
# 28                                    Hotel       1978             68410
# 29                              K-12 School       1949            160645
# ...                                     ...        ...               ...
# 9890                            Multifamily       2016            273568
# 9891                            Multifamily       2016             25688
# 9892                            Multifamily       2016            281300
# 9893                            Multifamily       2016             44192
# 9894                            Senior Care       2016            139061
# 9895                            Multifamily       2016            185611
# 9896                            Multifamily       2016             50726
# 9897                            Multifamily       2016             44294
# 9898                            Multifamily       2016            426320
# 9899                                 Office       2016            213803
# 9900                            Multifamily       2017             29317
# 9901                                 Office       2016             95576
# 9902                            Multifamily       2016             60500
# 9903                            Multifamily       2016             75494
# 9904                                 Office       2016             37100
# 9905                            Other - Rec       2005             20616
# 9906                            Other - Rec       1912             23445
# 9907                            Other - Rec       1994             20050
# 9908                                 Office       2016            240700
# 9909                            Multifamily       2016            144820
# 9910                            Multifamily       2016            153742
# 9911                            Multifamily       2016            187070
# 9912                            Multifamily       2017            137771
# 9913                            Multifamily       2014            129280
# 9914                            Multifamily       2016            320566
# 9915                            Multifamily       2015           1464631
# 9916                            Multifamily       2016             69656
# 9917                            Multifamily       2015             20838
# 9918                            Multifamily       2015             67505
# 9919                            Multifamily       2000             63928
#
#       SiteEUI(kBtu/sf)  SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  \
# 0            78.900000           80.300000          173.500000
# 1            94.400000           99.000000          191.300000
# 2            96.600000           99.700000          242.700000
# 3           120.100000          122.100000          228.800000
# 4           135.700000          146.900000          313.500000
# 5            76.900000           79.600000          149.500000
# 6            62.500000           71.800000          152.200000
# 7            77.000000           82.900000          174.600000
# 8            81.700000           92.700000          178.100000
# 9           101.100000          107.200000          200.800000
# 10           82.300000           83.100000          207.200000
# 11          104.700000           96.800000          166.500000
# 12           77.200000           77.200000          183.200000
# 13          166.100000          175.700000          317.400000
# 14           46.000000           45.300000          140.800000
# 15           79.500000           83.400000          173.700000
# 21               0.0       9.116590e+05      5.426000e+05
# 22               0.0       2.254751e+06      1.626149e+06
# 23               0.0       4.582663e+06      5.209084e+06
# 24               0.0       1.388775e+06      0.000000e+00
# 25               0.0       5.327470e+05      4.626617e+06
# 26               0.0       5.763595e+06      5.263590e+06
# 27               0.0       1.933106e+06      4.350200e+06
# 28               0.0       2.276244e+06      2.065556e+06
# 29               0.0       1.709681e+06      4.678100e+06
# ...              ...                ...               ...
# 9890             0.0       3.060135e+06      3.740914e+06
# 9891             0.0       5.298549e+05      2.854500e+05
# 9892             0.0       7.741350e+05      2.505967e+06
# 9893             0.0       1.447625e+06      3.254300e+04
# 9894             0.0       3.506061e+06      2.977712e+06
# 9895             0.0       2.276776e+06      1.761261e+06
# 9896             0.0       1.649097e+06      0.000000e+00
# 9897             0.0       6.393852e+05      4.600340e+05
# 9898             0.0       3.953516e+06      3.383255e+06
# 9899             0.0       6.169208e+06      0.000000e+00
# 9900             0.0       5.506193e+05      0.000000e+00
# 9901             0.0       2.973700e+06      0.000000e+00
# 9902             0.0       1.158435e+06      7.743380e+05
# 9903             0.0       1.941483e+06      0.000000e+00
# 9904             0.0       9.438397e+05      2.977740e+05
# 9905             0.0       7.447956e+05      0.000000e+00
# 9906             0.0       1.650977e+06      5.369599e+06
# 9907             0.0       8.912929e+05      1.089769e+06
# 9908             0.0       9.273325e+06      0.000000e+00
# 9909             0.0       7.887022e+05      1.255904e+06
# 9910             0.0       2.015081e+06      1.912293e+06
# 9911             0.0       1.717677e+06      1.718554e+06
# 9912             0.0       2.564612e+06      8.446337e+05
# 9913             0.0       2.061061e+06      8.026560e+05
# 9914             0.0       4.140482e+06      2.953182e+06
# 9915             0.0       1.493642e+07      1.072777e+07
# 9916             0.0       5.740574e+05      7.750229e+05
# 9917             0.0       5.024859e+05      3.999970e+05
# 9918             0.0       1.823499e+06      0.000000e+00
# 9919             0.0       1.598505e+06      1.971293e+06
#
# [9920 rows x 18 columns]

# %%
data_combined.to_csv(r'C:\Users\cjros\DIRECT\Capstone\Data\EnergyConsumption\Seattle\Seattle_Energy_Consumption_cleaned.csv', index_label='UID')

# %% [markdown]
# ### Code to trim Seattle building energy data into for consistent buildings year to year

# %%
data_trimmed = data_combined[data_combined.groupby(['BuildingID'])['BuildingID'].transform('size') > 2]
data_trimmed.sort_values(by='BuildingID')
data_trimmed
# Out:
# Empty DataFrame
# Columns: [BuildingID, DataYear, City, State, ZipCode, BuildingType, PrimaryPropertyUse, YearBuilt, PropertyGFATotal, SiteEUI(kBtu/sf), SiteEUIWN(kBtu/sf), SourceEUI(kBtu/sf), SourceEUIWN(kBtu/sf), SiteEnergyUse(kBtu), SiteEnergyUseWN(kBtu), SteamUse(kBtu), Electricity(kBtu), NaturalGas(kBtu)]
# Index: []

# %%
#data_combined.to_csv(r'C:\Users\cjros\DIRECT\Capstone\Data\EnergyConsumption\Seattle\Seattle_Energy_Consumption_trimmed.csv', index_label='RID')
